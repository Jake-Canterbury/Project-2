# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_excel('/content/drive/MyDrive/Coding_Dojo!/Week_7-MLAI/wealth_tables_2011.xlsx')
df.head()
# Out:
#   Table with row headers in column A and column headers in row 4. (Leading dots indicate subparts)  \
# 0  Table 1. Median Value of Assets for Households...
# 1                                                NaN
# 2                                     Characteristic
# 3                                              TOTAL
# 4            RACE AND HISPANIC ORIGIN OF HOUSEHOLDER
#
#   Unnamed: 1                                Unnamed: 2  \
# 0        NaN                                       NaN
# 1        NaN                                       NaN
# 2  Net Worth  Net Worth (Excluding Equity in Own Home)
# 3      68828                                     16942
# 4        NaN                                       NaN
#
#                                           Unnamed: 3  \
# 0                                                NaN
# 1                                                NaN
# 2  Interest Earning Assets at Financial Institutions
# ...

# %% [markdown]
# 1. United States Census Bureau
#
# 2. Data from Wealth and Asset Ownership: 2011 data
#
# 3. Equity in own home
#
# 4. regression
#
# 5. 14
#
# 6. 90
#
# 7. Cleaning may be difficult dealing with missing or incorrect numerical data

# %%
df = pd.read_csv('/content/drive/MyDrive/Coding_Dojo!/Week_7-MLAI/Uber-Jan-Feb-FOIL.csv')
df.head()
# Out:
#   dispatching_base_number      date  active_vehicles  trips
# 0                  B02512  1/1/2015              190   1132
# 1                  B02765  1/1/2015              225   1765
# 2                  B02764  1/1/2015             3427  29421
# 3                  B02682  1/1/2015              945   7679
# 4                  B02617  1/1/2015             1228   9537

# %% [markdown]
# 1. Uber
#
# 2. This directory contains data on over 4.5 million Uber pickups in New York City from April to September 2014, and 14.3 million more Uber pickups from January to June 2015. Trip-level data on 10 other for-hire vehicle (FHV) companies, as well as aggregated data for 329 FHV companies, is also included.
#
# 3. trips
#
# 4. regression
#
# 5. 4
#
# 6. 354
#
# 7. small number of features over a limited timeframe
